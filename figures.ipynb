# %% [markdown]
# # Generate figures

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_4node_test.csv', header = 0)
#df = df.drop(['Label'], axis=1)
df.head()
# Out:
#    B0  B1  B2  B3  Label
# 0 -73 -96 -85 -71      1
# 1 -59 -74 -85 -72      1
# 2 -55 -61 -85 -77      1
# 3 -74 -75 -73 -71      1
# 4 -72 -80 -83 -63      1

# %%
ax = df.plot(x='Label', y=['B0','B1','B2','B3'], style='o',figsize=(10,5), title = "Visualizing collected data", xlim = (0,17), ylim = (-30, -100))
ax.set_xlabel("Location as class labels")
ax.set_ylabel("RSSI values")
plt.show()

# %%
fig = ax.get_figure()
fig.savefig("chart1")

# %%
df1 = pd.read_csv('data_2node_test.csv', header = 0)
#df = df.drop(['Label'], axis=1)
df1.head()
# Out:
#   B0 B1 Label
# 0  F  N     a
# 1  N  F     a
# 2  F  N     a
# 3  F  F     a
# 4  F  N     a
